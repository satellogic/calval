# %%
import os
import glob
import pytest
from datetime import datetime

import numpy as np

from radcalnet.site_measurements import SiteMeasurements
from radcalnet.data_store import DataStore
from calval.satellites.srf import SRF, Sentinel2Red, Sentinel2Green, Sentinel2Blue
from calval.analysis import integrate, plot
# Out:
# /home/slava/Envs/calval/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# pathlist = glob.glob(os.path.join('../tests', 'data', 'datastore', 'BTCN', '*'))
# sm = SiteMeasurements.from_pathlist(pathlist)[datetime(2018, 5, 28): datetime(2018, 5, 29)]
ds = DataStore('/home/slava/Downloads/Radcalnet_alldata')
# ds = DataStore(os.path.join('../tests', 'data', 'datastore'))
sm = ds.get_measuremets('BTCN', datetime(2018, 5, 28), datetime(2018, 5, 29))

srfs = [Sentinel2Blue(), Sentinel2Green(), Sentinel2Red()]
plot(['toa', 'sr'], sm, srfs, show=False);
